# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.25.1
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache 2.0
# Location: c:\users\vega2\anaconda3\lib\site-packages
# Requires: urllib3, certifi, chardet, idna
# Required-by: Sphinx, jupyterlab-server, conda, conda-repo-cli, conda-build, anaconda-project, anaconda-client

# %%
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.9.3
# Summary: Screen-scraping library
# Home-page: http://www.crummy.com/software/BeautifulSoup/bs4/
# Author: Leonard Richardson
# Author-email: leonardr@segfault.org
# License: MIT
# Location: c:\users\vega2\anaconda3\lib\site-packages
# Requires: soupsieve
# Required-by: conda-build

# %% [markdown]
# ### 네이버 뉴스제목 검색하기
# * user-agent 헤더값을 반드시 설정

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://news.naver.com/'
req_header = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'
}
res = requests.get(url, headers=req_header)
print(type(res))
#res = requests.get(url)
print(res.ok)
print(res.status_code)
if res.ok:
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    print(len(soup.select("a[href*='read.naver']")))
    a_tag_list = soup.select("a[href*='read.naver']")
    for idx,a_tag in enumerate(a_tag_list):
        #print(type(a_tag), a_tag)
        title = a_tag.text.strip()
        if title:
            print(idx, title)
            print(a_tag[href])
# Out:
# <class 'requests.models.Response'>
# True
# 200
# 197
# 0 文대통령 호평한 동탄 임대주택, 9개월째 공실
# 1 이준석 "곽상도 엄격 대응"…윤리위 제명 언급
# 2 소아 청소년 임신부 백신 맞고 접종 간격 1~2주씩 당긴다
# 3 2289명 확진, 월요일 최다…일평균 나흘째 2000명대(상보)
# 4 SK이노, 美포드 배터리 합작사에 5조1175억 투자
# 5 넷플릭스 CEO "韓 오징어게임, 가장 큰 작품 될 수도"
# 6 윤호중 “언론중재법 오늘 처리 위해 최대한 협의할 것”
# 7 [단독]국세청, '민원 붙박이' 시간제공무원, 2022년부터 처우 개선
# 8 진중권 "이재명, 결백하면 특검 수용하고 한동훈이 수사해야"
# 9 유승민 측, 이재명에 "도박판 호구보다 설계자가 더 나쁘다" 직격
# 10 화천대유가 내년 대구시장 선거판 흔든다
# 11 김여정의 종전선언 조건, 한미연합훈련 중단?…北 “입장 다 나왔다”
# 13 문 대통령 다녀간 동탄 행복주택, 9개월째 비었다
# 14 '헝다 사태' 신경쓰는 中중앙은행 "주택구매자 합법적 이익 옹호"
# 15 DK아시아·DK도시개발, 아시아건설종합대상서 국토부 장관 표창 수상
# 16 다주택자 이 정도일 줄이야…서울 빌라값, 4년전 아파트값[식후땡 부동산]
# 17 국토교통부 “남해-여수, 해저터널 만들어 연결”
# 18 [코인브리핑] JP모건 CEO "빚내서 비트코인 투자하면 바보"
# 20 운전자 의식 잃고 중앙선 넘어오던 차···자신의 차로 막은 시민영웅
# 21 문 열린 집 노인만 노렸다...돈 빼앗고 성폭행 시도까지 한 50대
# 22 "속옷만 입고…" 유튜버가 거절한 '오징어게임 반라소파女' 출연료
# 23 40대 공무원, 화이자 2차 접종 후 10일 뒤 숨져… "기저질환 없어"
# 24 권덕철 장관 "먹는 코로나 치료제 예산, 추가확보 계획"
# 25 “급하게 돈 쓸 일이 생겼다”…남성팬에 8000만원 뜯어낸 여성 BJ
# 26 동영상 기사
# 27 [날씨] 곳곳 산발적 빗방울…차츰 전국 가을비
# 28 [오후날씨 꿀팁] 오후에 서해안부터 비…내일은 전국 비
# 29 [날씨] '20~70mm' 비 예보…내일 중부 중심 '강한 비'
# 30 역주행하는 초보 본 운전자의 따뜻한 배려… "경적 한번 안 울리더라"[영상]
# 31 [오후날씨 꿀팁] 오후, 중부 서해안부터 비…내일은 전국에 비
# 32 [날씨] 수도권·전남 해안 약한 비‥서울, 한낮 24도 안팎
# 34 [줌인] 에너지 대란에 원전으로 다시 눈 돌리는 영국
# 35 일본 정부, 코로나19 긴급사태 선언 30일로 전면 해제
# 36 日 이어 美도 '북한 탄도미사일'에 무게…미군은 "즉각 위협 아냐"
# 37 미국 뉴욕, 코로나19 백신 접종 거부한 의료 인력 해고·휴직 사태 현실화…'의료 대란' 여부 주목
# 38 40년 출산 제한하더니…중국 ‘비의료적 이유’ 임신중단 제한
# 39 日 "北발사체, 탄도미사일 가능성…EEZ내 추락가능성 낮아"(종합)
# 41 [이광식의 천문학+] 우리 우주 너머 또다른 우주가 있을까?…다중우주, 평행우주론
# 42 '엘살바도르 처럼"...비트코인 법정화폐 활용 국가 늘어난다
# 43 "안산 7점 최악" 해설 논란…KBSN "선수·시청자께 사과"
# 44 [스마트클라우드쇼 2021] 제나 리 MS 총괄 “메타버스로 미래도 예측…비즈니스 혁명 가져올 것”
# 45 [산업리포트]5G 특화망, B2B 시장 새 기회 열린다
# 46 [스마트클라우드쇼 2021] 전진수 SKT CO장 “이프랜드 내 하루 수천개 공간 생성…메타버스로 코로나 답답함 해소”
# 48 1.5L 콜라 10분만에 원샷후 사망…CT 본 의사 깜짝  …
# 50 전세 싸게 얻었다 했더니 신탁물건 사기... 하루아침에 ' …
# 52 만취 난동으로 식당서 쫓겨난 노숙자? 알고 보니 니콜라스  …
# 54 '4억 로또분양' 대박 조짐...특공 경쟁률 166.8대  …
# 56 곽상도 아들의 50억, 목숨 잃은 노동자의 1억
# 57 동영상기사
# 58 [재택플러스] '한국 놀이' 원더풀‥오징어게임 신드롬
# 60 윤석열 "몸통은 이재명…내가 대통령 되면 화천대유 주인 감 …
# 62 구독자 140만 '떡상' 유튜버 식빵언니 김연경…8개월만에 …
# 64 중고 냉장고 샀더니 따라온 현금 1억여 원…주인 찾았다
# 66 "이웃집으로 잘못 배달 된 추석 선물, 다 먹었대요"…책임 …
# 68 김형석 "대리 직급 없어질 듯"…'50억 퇴직금' 곽상도  …
# 70 정부, 계란 한 판 1.2만원에 수입해 3천원에 팔아…천억 …
# 72 스타벅스, 오늘 하루 전국 매장서 다회용 컵에 음료 제공
# 74 윤석열 "대장동 게이트 몸통은 이재명"
# 76 여수 ‘층간소음’ 참극 이웃 증언…“매트도 깔고 샤워만 했 …
# 78 지난해 사망자 수 30만명 첫 돌파…‘인구 데드크로스’
# 80 제주로 배달된 중고냉장고 바닥 현금 1억1000만원 주인  …
# 82 배달기사가 "결제 안 됐다"며 시간 끌었던 이유는
# 84 중고 냉장고서 발견된 1억…주인은 서울 60대 여성
# 86 안산 7점 쏘자 “최악이다, 이게 뭐냐”…KBS 해설 논란
# 87 동영상기사
# 88 화이자, '알약 형태' 코로나 치료제 2상 임상시험 개시
# 90 [단독] 현직 기상캐스터, '면허 정지 수준' 음주운전…벌 …
# 92 "술·담배 안 한 건강한 남편 AZ 맞고 숨져···그냥 있 …
# 94 [단독]‘대장동 1007억’ 챙긴 남욱, 강남 노른자위 건 …
# 96 “손목 힘줄이며 신경 다 잘렸다”…산책하는 연인에 흉기 휘 …
# 98 이준석 "곽상도 아들 '50억', 장제원 아들 일탈과 달라 …
# 100 [단독]‘천화동인’ 멤버들, 대장동 개발前 땅 32% 사뒀 …
# 102 "속옷만 입으라해 거절했는데"...'오징어게임' 인간소파女 …
# 104 [단독]삼성家 이서현, 상속세 담보로 2조원대 삼성전자 주 …
# 105 동영상기사
# 106 코스피, 외국인·기관 매도에 3100선 후퇴…네이버·카카오 …
# 108 이준석, ‘곽상도 연루’ 알고도 대선주자 “화천대유 하십쇼 …
# 110 장제원 "자식 잘 못 키운 아비의 죄 반성" 尹 캠프 상황 …
# 112 중고 김치냉장고서 발견된 ‘1억 돈다발’… 주인 찾았지만  …
# 114 윤석열 캠프 "노부모 패륜 취재" 열공TV "범죄자 취급해 …
# 116 [속보] 정부 "현행 거리두기 유지 어려운 상황…일상회복  …
# 118 "두달간 1인당 최대 20만원" 상생소비지원금 시행
# 120 ‘버전 2.0’으로 돌아온 탈레반, 그들이 진화한 두 가지 …
# 122 반도체 초강국 이끌 '최상위 협의체' 출범
# 124 [초점] SK이노-포드, 美 최대규모 배터리공장 건설…전기 …
# 126 [단독]곽상도, 의원직 당장 사퇴 안 한다…“검찰 수사 후 …
# 128 오징어 게임 전화번호 산다고?…수천만원 과태료 낼수도
# 130 “왜 남동생만 상속 많이 받나” 소송 제기한 누나들 [법알 …
# 132 이준석 "곽상도 엄격 대응"…윤리위 제명 언급
# 134 "가정 쑥대밭…" 노엘 아버지 장제원 SNS에 남긴 글
# 136 [속보] 안산 7점 쏘자 "최악" 비하 발언 논란 KBSN …
# 138 [속보]권덕철 복지부 장관 '위드 코로나' 전환 10월말∼ …
# 140 "어렵게 당첨됐는데" 대출 막힌 실수요자들 분통
# 142 [속보] 코로나 신규확진 2289명…3일째 2000명대
# 144 이정재가 입은 초록색 운동복 가격이…‘오징어게임’ 굿즈도  …
# 146 '규모의 경제'에 올인 SK이노베이션, 포드 합작사에 5조 …
# 148 리니지 모델 안 먹히네! 사면초가 ‘택진이형’의 딜레마
# 150 Time to review banning dog meat: …
# 152 경남-김경수 도지사 중도하차한 뒤 경남은?
# 154 여성 뱃살 붙는 '세 번'의 위기… 막으려면?
# 156 [검찰의 사냥법] ③ 서울남부지검이 덮은 두번째 '원유철  …
# 158 [대선주자 주택공약 진단] ①이재명 사상 최대 250만호  …
# 160 특히 중년 여성에게 좋은 운동 5
# 162 서울지노위 "스포츠서울 임직원 14명 정리해고는 부당"
# 164 장제원, 결국 尹캠프 총괄실장 사퇴…"가정 쑥대밭 됐다"
# 166 "넣어도 돼요?"… 초등학교 6학년 남학생, 담임교사 성희 …
# 168 원준·아스플로·씨유테크·케이카 등 4곳 이번 주 공모주 청 …
# 170 '시세보다 싼' 청년·신혼 매입임대주택 입주자모집공고
# 172 미투운동 ‘이후’ 이야기해야 하는 것들
# 174 국민 90% "코로나 종식 불가능... 독감처럼 계속 백신 …
# 176 DL 아파트 리모델링 시장서 약진… 대형 건설사 ‘적과 동 …
# 178 [신안특집] 김환기의 고향 안좌도, 보랏빛으로 물들다
# 180 North’s missile is sixth major w …
# 182 [단독]北 물자부족 비상, 中 파견노동자에 생필품 헌납 지 …
# 184 연일 확진자 쏟아져도 '위드 코로나' 계획대로 간다  …
# 186 “백신 부작용 감수하며 맞아야 하나” 20~30대 접종 꺼 …
# 188 North’s missile is sixth major w …
# 190 [단독]北 물자부족 비상, 中 파견노동자에 생필품 헌납 지 …
# 192 연일 확진자 쏟아져도 '위드 코로나' 계획대로 간다  …
# 194 “백신 부작용 감수하며 맞아야 하나” 20~30대 접종 꺼 …
# 196 [임성용의 보약밥상] 수술 앞둔 사람은 피해야 할 ‘은행’
